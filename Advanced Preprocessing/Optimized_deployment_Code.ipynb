# %%
# import pandas as pd
# dataset=pd.read_csv('insurance_pre.csv')
# dataset=pd.get_dummies(dataset,drop_first=True)
# independent= dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
# dependent= dataset[['charges']]
# from sklearn.model_selection import train_test_split
# x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.2,random_state=0)

# %%
# #applying standarisation
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# x_train=sc.fit_transform(x_train)
# x_test=sc.transform(x_test)

# scy=StandardScaler()
# y_train=scy.fit_transform(y_train)
# y_test=scy.transform(y_test)

# %%
#Loading all the artifacts
import pickle
input_scalar=pickle.load(open("input_scalar.pkl",'rb'))
output_scalar=pickle.load(open("output_scalar.pkl",'rb'))
loaded_model=pickle.load(open("final_model.pkl",'rb'))

# %%
#preprocessing the input before passing to the model
scaled_input=input_scalar.transform([[35,30,1,0,0]])
scaled_input
# Out:
# C:\Users\ACER\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.29056198, -0.11773994, -0.06565939, -0.98515688, -0.50729114]])

# %%
#predict the result
raw_output=loaded_model.predict(scaled_input)
raw_output
# Out:
# array([-0.56620447])

# %%
#Reversing format of output
final_result=output_scalar.inverse_transform([raw_output])
final_result
# Out:
# array([[6421.698606]])
